# %%
import numpy as np
import pandas as pd
from pathlib import Path
import pandas as pd
import sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn import tree
p = pd.read_csv("MixedSet2.csv")

data = pd.read_csv(p)

# %%
X =  data.iloc[:, :-1].values
print(X)
y = data.iloc[:, -1].values
print(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 X =  data.iloc[:, :-1].values
#       2 print(X)
#       3 y = data.iloc[:, -1].values
#
# NameError: name 'data' is not defined

# %%
dimensionality_reduction = data.groupby(data['problem']).max()
print(dimensionality_reduction)
# Out:
#                                                     symptomA_Car exhaust smoke  \
# problem
# A new head gasket may be needed                                              1
# Check for a vacuum leak or moisture in the dist...                           0
# Check if the air filter is clean. If so then ch...                           1
# Check the balance of the four wheels                                         0
# Lack of coolant                                                              0
# Matching problem between the brake pads and the...                           0
# The alternator belt may be slipping or the fan ...                           0
# The cooling system is clogged - it needs to be ...                           0
# The engine sensor may be damaged                                             1
# The engine sensor may be faulty                                              1
# This is a normal situation                                                   1
# This is a normal situation. The anti lock syste...                           0
# check the ventilation unit                                                   0
#
#                                                     symptomA_High engine temperature  \
# problem
# A new head gasket may be needed                                                    0
# Check for a vacuum leak or moisture in the dist...                                 0
# Check if the air filter is clean. If so then ch...                                 0
# Check the balance of the four wheels                                               0
# Lack of coolant                                                                    1
# Matching problem between the brake pads and the...                                 0
# The alternator belt may be slipping or the fan ...                                 1
# The cooling system is clogged - it needs to be ...                                 1
# The engine sensor may be damaged                                                   0
# The engine sensor may be faulty                                                    0
# This is a normal situation                                                         0
# This is a normal situation. The anti lock syste...                                 0
# check the ventilation unit                                                         1
#
#                                                     symptomA_The car shakes  \
# problem
# A new head gasket may be needed                                           0
# Check for a vacuum leak or moisture in the dist...                        1
# Check if the air filter is clean. If so then ch...                        0
# Check the balance of the four wheels                                      1
# Lack of coolant                                                           0
# Matching problem between the brake pads and the...                        1
# The alternator belt may be slipping or the fan ...                        0
# The cooling system is clogged - it needs to be ...                        0
# The engine sensor may be damaged                                          0
# The engine sensor may be faulty                                           0
# This is a normal situation                                                0
# This is a normal situation. The anti lock syste...                        1
# check the ventilation unit                                                0
#
#                                                     symptomB_After a long drive  \
# problem
# A new head gasket may be needed                                               0
# Check for a vacuum leak or moisture in the dist...                            0
# Check if the air filter is clean. If so then ch...                            0
# Check the balance of the four wheels                                          0
# Lack of coolant                                                               0
# Matching problem between the brake pads and the...                            0
# The alternator belt may be slipping or the fan ...                            1
# The cooling system is clogged - it needs to be ...                            0
# The engine sensor may be damaged                                              0
# The engine sensor may be faulty                                               0
# This is a normal situation                                                    0
# This is a normal situation. The anti lock syste...                            0
# check the ventilation unit                                                    1
#
#                                                     symptomB_Hot weather  \
# problem
# A new head gasket may be needed                                        0
# Check for a vacuum leak or moisture in the dist...                     0
# Check if the air filter is clean. If so then ch...                     0
# Check the balance of the four wheels                                   0
# Lack of coolant                                                        1
# Matching problem between the brake pads and the...                     0
# The alternator belt may be slipping or the fan ...                     0
# The cooling system is clogged - it needs to be ...                     1
# The engine sensor may be damaged                                       0
# The engine sensor may be faulty                                        0
# This is a normal situation                                             0
# This is a normal situation. The anti lock syste...                     0
# check the ventilation unit                                             0
#
#                                                     symptomB_The brake pedal is shaking  \
# problem
# A new head gasket may be needed                                                       0
# Check for a vacuum leak or moisture in the dist...                                    0
# Check if the air filter is clean. If so then ch...                                    0
# Check the balance of the four wheels                                                  0
# Lack of coolant                                                                       0
# Matching problem between the brake pads and the...                                    1
# The alternator belt may be slipping or the fan ...                                    0
# The cooling system is clogged - it needs to be ...                                    0
# The engine sensor may be damaged                                                      0
# The engine sensor may be faulty                                                       0
# This is a normal situation                                                            0
# This is a normal situation. The anti lock syste...                                    1
# check the ventilation unit                                                            0
#
#                                                     symptomB_The steering wheel shakes  \
# problem
# A new head gasket may be needed                                                      0
# Check for a vacuum leak or moisture in the dist...                                   0
# Check if the air filter is clean. If so then ch...                                   0
# Check the balance of the four wheels                                                 0
# Lack of coolant                                                                      0
# Matching problem between the brake pads and the...                                   1
# The alternator belt may be slipping or the fan ...                                   0
# The cooling system is clogged - it needs to be ...                                   0
# The engine sensor may be damaged                                                     0
# The engine sensor may be faulty                                                      0
# This is a normal situation                                                           0
# This is a normal situation. The anti lock syste...                                   0
# check the ventilation unit                                                           0
#
#                                                     symptomB_The whole car shakes  \
# problem
# A new head gasket may be needed                                                 0
# Check for a vacuum leak or moisture in the dist...                              1
# Check if the air filter is clean. If so then ch...                              0
# Check the balance of the four wheels                                            1
# Lack of coolant                                                                 0
# Matching problem between the brake pads and the...                              1
# The alternator belt may be slipping or the fan ...                              0
# The cooling system is clogged - it needs to be ...                              0
# The engine sensor may be damaged                                                0
# The engine sensor may be faulty                                                 0
# This is a normal situation                                                      0
# This is a normal situation. The anti lock syste...                              0
# check the ventilation unit                                                      0
#
#                                                     symptomB_black smoke  \
# problem
# A new head gasket may be needed                                        0
# Check for a vacuum leak or moisture in the dist...                     0
# Check if the air filter is clean. If so then ch...                     1
# Check the balance of the four wheels                                   0
# Lack of coolant                                                        0
# Matching problem between the brake pads and the...                     0
# The alternator belt may be slipping or the fan ...                     0
# The cooling system is clogged - it needs to be ...                     0
# The engine sensor may be damaged                                       0
# The engine sensor may be faulty                                        1
# This is a normal situation                                             0
# This is a normal situation. The anti lock syste...                     0
# check the ventilation unit                                             0
#
#                                                     symptomB_white smoke  ...  \
# problem                                                                   ...
# A new head gasket may be needed                                        1  ...
# Check for a vacuum leak or moisture in the dist...                     0  ...
# Check if the air filter is clean. If so then ch...                     0  ...
# Check the balance of the four wheels                                   0  ...
# Lack of coolant                                                        0  ...
# Matching problem between the brake pads and the...                     0  ...
# The alternator belt may be slipping or the fan ...                     0  ...
# The cooling system is clogged - it needs to be ...                     0  ...
# The engine sensor may be damaged                                       1  ...
# The engine sensor may be faulty                                        0  ...
# This is a normal situation                                             1  ...
# This is a normal situation. The anti lock syste...                     0  ...
# check the ventilation unit                                             0  ...
#
#                                                     symptomC_The air conditioner is on most of the time  \
# problem
# A new head gasket may be needed                                                                     0
# Check for a vacuum leak or moisture in the dist...                                                  0
# Check if the air filter is clean. If so then ch...                                                  0
# Check the balance of the four wheels                                                                0
# Lack of coolant                                                                                     0
# Matching problem between the brake pads and the...                                                  0
# The alternator belt may be slipping or the fan ...                                                  0
# The cooling system is clogged - it needs to be ...                                                  0
# The engine sensor may be damaged                                                                    0
# The engine sensor may be faulty                                                                     0
# This is a normal situation                                                                          0
# This is a normal situation. The anti lock syste...                                                  0
# check the ventilation unit                                                                          1
#
#                                                     symptomC_The braking also has vibrations from the front  \
# problem
# A new head gasket may be needed                                                                     0
# Check for a vacuum leak or moisture in the dist...                                                  0
# Check if the air filter is clean. If so then ch...                                                  0
# Check the balance of the four wheels                                                                0
# Lack of coolant                                                                                     0
# Matching problem between the brake pads and the...                                                  1
# The alternator belt may be slipping or the fan ...                                                  0
# The cooling system is clogged - it needs to be ...                                                  0
# The engine sensor may be damaged                                                                    0
# The engine sensor may be faulty                                                                     0
# This is a normal situation                                                                          0
# This is a normal situation. The anti lock syste...                                                  0
# check the ventilation unit                                                                          0
#
#                                                     symptomC_The smoke comes out during startup and then stops  \
# problem
# A new head gasket may be needed                                                                     0
# Check for a vacuum leak or moisture in the dist...                                                  0
# Check if the air filter is clean. If so then ch...                                                  0
# Check the balance of the four wheels                                                                0
# Lack of coolant                                                                                     0
# Matching problem between the brake pads and the...                                                  0
# The alternator belt may be slipping or the fan ...                                                  0
# The cooling system is clogged - it needs to be ...                                                  0
# The engine sensor may be damaged                                                                    1
# The engine sensor may be faulty                                                                     0
# This is a normal situation                                                                          0
# This is a normal situation. The anti lock syste...                                                  0
# check the ventilation unit                                                                          0
#
#                                                     symptomC_The smoke comes out of the exhaust when starting and then stops  \
# problem
# A new head gasket may be needed                                                                     0
# Check for a vacuum leak or moisture in the dist...                                                  0
# Check if the air filter is clean. If so then ch...                                                  0
# Check the balance of the four wheels                                                                0
# Lack of coolant                                                                                     0
# Matching problem between the brake pads and the...                                                  0
# The alternator belt may be slipping or the fan ...                                                  0
# The cooling system is clogged - it needs to be ...                                                  0
# The engine sensor may be damaged                                                                    0
# The engine sensor may be faulty                                                                     1
# This is a normal situation                                                                          0
# This is a normal situation. The anti lock syste...                                                  0
# check the ventilation unit                                                                          0
#
#                                                     symptomC_The smoke comes out of the exhaust while driving  \
# problem
# A new head gasket may be needed                                                                     0
# Check for a vacuum leak or moisture in the dist...                                                  0
# Check if the air filter is clean. If so then ch...                                                  1
# Check the balance of the four wheels                                                                0
# Lack of coolant                                                                                     0
# Matching problem between the brake pads and the...                                                  0
# The alternator belt may be slipping or the fan ...                                                  0
# The cooling system is clogged - it needs to be ...                                                  0
# The engine sensor may be damaged                                                                    0
# The engine sensor may be faulty                                                                     0
# This is a normal situation                                                                          0
# This is a normal situation. The anti lock syste...                                                  0
# check the ventilation unit                                                                          0
#
#                                                     symptomC_The smoke comes out of the exhaust while driving and stops after the engine has warmed up  \
# problem
# A new head gasket may be needed                                                                     0
# Check for a vacuum leak or moisture in the dist...                                                  0
# Check if the air filter is clean. If so then ch...                                                  0
# Check the balance of the four wheels                                                                0
# Lack of coolant                                                                                     0
# Matching problem between the brake pads and the...                                                  0
# The alternator belt may be slipping or the fan ...                                                  0
# The cooling system is clogged - it needs to be ...                                                  0
# The engine sensor may be damaged                                                                    0
# The engine sensor may be faulty                                                                     0
# This is a normal situation                                                                          1
# This is a normal situation. The anti lock syste...                                                  0
# check the ventilation unit                                                                          0
#
#                                                     symptomC_The smoke comes out of the exhaust while driving even after the engine has warmed up  \
# problem
# A new head gasket may be needed                                                                     1
# Check for a vacuum leak or moisture in the dist...                                                  0
# Check if the air filter is clean. If so then ch...                                                  0
# Check the balance of the four wheels                                                                0
# Lack of coolant                                                                                     0
# Matching problem between the brake pads and the...                                                  0
# The alternator belt may be slipping or the fan ...                                                  0
# The cooling system is clogged - it needs to be ...                                                  0
# The engine sensor may be damaged                                                                    0
# The engine sensor may be faulty                                                                     0
# This is a normal situation                                                                          0
# This is a normal situation. The anti lock syste...                                                  0
# check the ventilation unit                                                                          0
#
#                                                     symptomC_cold weather  \
# problem
# A new head gasket may be needed                                         0
# Check for a vacuum leak or moisture in the dist...                      0
# Check if the air filter is clean. If so then ch...                      0
# Check the balance of the four wheels                                    0
# Lack of coolant                                                         0
# Matching problem between the brake pads and the...                      0
# The alternator belt may be slipping or the fan ...                      0
# The cooling system is clogged - it needs to be ...                      0
# The engine sensor may be damaged                                        0
# The engine sensor may be faulty                                         0
# This is a normal situation                                              1
# This is a normal situation. The anti lock syste...                      0
# check the ventilation unit                                              0
#
#                                                     symptomC_low coolant level warning light is on  \
# problem
# A new head gasket may be needed                                                                  0
# Check for a vacuum leak or moisture in the dist...                                               0
# Check if the air filter is clean. If so then ch...                                               0
# Check the balance of the four wheels                                                             0
# Lack of coolant                                                                                  1
# Matching problem between the brake pads and the...                                               0
# The alternator belt may be slipping or the fan ...                                               0
# The cooling system is clogged - it needs to be ...                                               0
# The engine sensor may be damaged                                                                 0
# The engine sensor may be faulty                                                                  0
# This is a normal situation                                                                       0
# This is a normal situation. The anti lock syste...                                               0
# check the ventilation unit                                                                       0
#
#                                                     symptomC_no low coolant level warning light is on
# problem
# A new head gasket may be needed                                                                     0
# Check for a vacuum leak or moisture in the dist...                                                  0
# Check if the air filter is clean. If so then ch...                                                  0
# Check the balance of the four wheels                                                                0
# Lack of coolant                                                                                     0
# Matching problem between the brake pads and the...                                                  0
# The alternator belt may be slipping or the fan ...                                                  0
# The cooling system is clogged - it needs to be ...                                                  1
# The engine sensor may be damaged                                                                    0
# The engine sensor may be faulty                                                                     0
# This is a normal situation                                                                          0
# This is a normal situation. The anti lock syste...                                                  0
# check the ventilation unit                                                                          0
#
# [13 rows x 25 columns]

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
y = labelencoder.fit_transform(y)
print(y)
# Out:
# [ 4  7 12  6  2  9  0 10 10  8  5  1  3  5 11  5]

# %%
model = tree.DecisionTreeClassifier()
model.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
model
# Out:
# DecisionTreeClassifier()

# %%
cols     = data.columns
cols     = cols[:-1]

# %%
importances = model.feature_importances_
indices = np.argsort(importances)[::-1]
features = cols

# %%
from sklearn.tree import _tree

# %%
def execute_bot():

    print("Please reply with yes/Yes or no/No for the following symptoms") 
    def print_problem(node):
        #print(node)
        node = node[0]
        #print(len(node))
        val  = node.nonzero() 
        #print(val)
        problem = labelencoder.inverse_transform(val[0])
        return problem
    def tree_to_code(tree, feature_names):
        tree_ = tree.tree_
        #print(tree_)
        feature_name = [
            feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!"
            for i in tree_.feature
        ]
        symptoms_present = []
        def recurse(node, depth):
            indent = "  " * depth
            if tree_.feature[node] != _tree.TREE_UNDEFINED:
                name = feature_name[node]
                threshold = tree_.threshold[node]
                print(name + " ?")
                ans = input()
                ans = ans.lower()
                if ans == 'yes':
                    val = 1
                else:
                    val = 0
                if  val <= threshold:
                    recurse(tree_.children_left[node], depth + 1)
                else:
                    symptoms_present.append(name)
                    recurse(tree_.children_right[node], depth + 1)
            else:
                present_problem = print_problem(tree_.value[node])
                
                print('The Model Suggests:')
                print()
                print( "You may have: " +  present_problem )
                print()
                row = CarDiagnose[CarDiagnose['problem'] == present_problem[0]]
                print('Description: ', str(row['Description'].values))
                print()
                print('Inspection List: ', str(row['InspectionList'].values))
    
        recurse(0, 1)
    
    tree_to_code(model,cols)

# %%
D = Path(r'E:/MSA/Fall 2023/Grad/CarDiagnose.csv')

Isnpection_dataset = pd.read_csv(D, names = ['Description','InspectionList'])

problem = dimensionality_reduction.index
problem = pd.DataFrame(problem)

CarDiagnose = pd.DataFrame()

CarDiagnose['Description'] = np.nan
CarDiagnose['InspectionList'] = np.nan

CarDiagnose['problem'] = np.nan
CarDiagnose['problem'] = problem['problem']


CarDiagnose['Description'] = Isnpection_dataset['Description']
CarDiagnose['InspectionList'] = Isnpection_dataset['InspectionList']

# %%
execute_bot()
# Out:
# Please reply with yes/Yes or no/No for the following symptoms
# symptomA_The car shakes ?
# symptomB_white smoke ?
# symptomC_Air conditioner is off most of the time ?
# The Model Suggests:
#
# ['You may have: The alternator belt may be slipping or the fan clutch may be damaged']
#
# Description:  ['Loose or worn suspension components will affect vehicle handling and wheel alignment. Loose wheel bearings\xa0and worn bushings can\xa0cause\xa0virbrations, pulling, and increased tire wear.']
#
# Inspection List:  ["1) Openthe hood and locate the top ofthesuspension strut mounts/shock towers. 2) Before starting any repairs, besure the vehicle is in park.Have an assistant push down on the fender to simulate driving over bumps. 3) Locate and Inspect the upper shock mounts on the inside of the engine compartment and underneath the wheel well for damage. 4) Closethe hood, then securethe vehicle on a level surface, making sure it will not roll or lean when jacked up. 5) Inspect the vehicle ride height (coil springs, struts, or torsion bars). Some owners manuals will have ride height specifications. The left and right side measurements should be equal. 6) Using a floor jack, lift the front ofthe vehicle. 7) Secure the vehicle with jack stands on both sides for safety before starting any work. The pinch welds or the frame rails are the two best locations. Do not rely on the jack to hold the vehicle. 8) Inspect all suspension grease boots for damage and make sure the boots are full of grease. 9) Use a grease gun and apply grease through the zerk fitting (grease fitting). When the grease begins to ooze from the joint, the boot is full. 10) Inspect sway bar mounts and end linkage for loose, bent, or missing components. Any damaged linkage will need to be replaced. 11) Inspect the control arms for damage to the bushings and ball joints. Bushing kits and ball joints are available for replacement; however, replacing the control arm assembly may also bean option. 12) Inspect the steering rack, steering box, steering column, and the inner tie rod linkage. 13) Inspect the outer tie rod ends for excessive play at the connection to the steering knuckle. You will also want to inspect the tie rod boots for damage.Note: On some vehicles, it may be necessary to remove the wheels to see and inspect the outer tie rod end. 14) Replace the necessary suspension system components and take the vehicle to a certified technician for proper alignment. 15) Test drive the vehicle and verify if there is suspension noise.']"]

# %%
import pickle

filename = 'savedmodel.sav'
pickle.dump(execute_bot,open(filename,'wb'))

# %%
load_model = pickle.load(open(filename,'rb'))

# %%
load_model()
# Out:
# Please reply with yes/Yes or no/No for the following symptoms
# symptomA_The car shakes ?
# symptomC_It only happens under heavy braking and there is no vibration from the front end ?
# symptomC_It happens while driving at a certain speed ?
# The Model Suggests:
#
# ['You may have: Check the balance of the four wheels']
#
# Description:  ['The constant heating and cooling of the exhaust manifold can cause leaks. You may catch a small crack before it becomes large enough to make a noise and become a more serious problem.']
#
# Inspection List:  ["1) Secure the vehicle on a level surface making sure the vehicle will not roll or lean when jacked up. 2) Using a jack, lift up the vehicle. Every vehicle comes from the factory with a jack. To locate and properly use this jack see the owners manual. The owners manual will inform you what proper jacking locations should be used. 3) Secure the vehicle with jack stands on both sides for safety before starting any work. The pinch welds or the frame rails are the two best locations to use. Do not rely on the jack to hold the vehicle up while working. 4) Inspect the entire exhaust system for damage. If your system has multiple sections that are rusted, cracked, or causing exhaust leaks, it is recommended that you install a new exhaust system into your vehicle.']"]
